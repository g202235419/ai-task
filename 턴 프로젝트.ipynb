# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

data = pd.read_excel('C:/Users/mandujoayo/데이터/턴프/의약품.xlsx', index_col=0)
data
# Out:
#                                                      2019   2020   2021
# ATC
# Digestive system and metabolism_A                   256.0  315.9  325.6
# Antacids_A02A                                         3.7    4.6    4.8
# Gastric ulcer treatment_A02B                         61.2   75.4   81.5
# Diabetes treatment_A10                               67.8   72.7   78.5
# Blood and hematopoietic system_B                     85.2   90.8   93.1
# Cardiovascular_C                                    221.8  240.3  254.9
# Cardiac glycosides_C01A                               0.9    1.0    0.9
# Venotropic agents_C01B                                1.6    1.8    2.0
# Antihypertensives_C02                                 1.8    1.9    1.9
# Diuretics_C03                                        14.4   15.4   15.8
# Beta-blockers_C07                                    13.0   14.0   14.4
# Calcium channel blockers_C08                         43.9   46.8   46.6
# ...

# %%
data.isnull().sum()
# Out:
# 2019    0
# 2020    0
# 2021    0
# dtype: int64

# %%
data.describe()
# Out:
#              2019        2020        2021
# count   28.000000   28.000000   28.000000
# mean    52.189286   56.692857   59.525000
# std     61.495169   71.614735   74.939608
# min      0.900000    1.000000    0.900000
# 25%     12.525000   13.075000   14.400000
# 50%     34.800000   32.050000   33.100000
# 75%     69.825000   76.500000   79.250000
# max    256.000000  315.900000  325.600000

# %%
data.mode()
# Out:
#      2019  2020  2021
# 0     0.9  14.0  14.4
# 1     1.6   NaN   NaN
# 2     1.8   NaN   NaN
# 3     3.7   NaN   NaN
# 4    10.2   NaN   NaN
# 5    11.6   NaN   NaN
# 6    12.3   NaN   NaN
# 7    12.6   NaN   NaN
# 8    13.0   NaN   NaN
# 9    13.5   NaN   NaN
# 10   14.4   NaN   NaN
# 11   23.4   NaN   NaN
# 12   26.1   NaN   NaN
# 13   34.5   NaN   NaN
# 14   35.1   NaN   NaN
# 15   43.9   NaN   NaN
# 16   47.6   NaN   NaN
# 17   48.0   NaN   NaN
# 18   50.5   NaN   NaN
# 19   61.2   NaN   NaN
# 20   67.8   NaN   NaN
# 21   75.9   NaN   NaN
# 22   78.4   NaN   NaN
# 23   85.2   NaN   NaN
# 24   95.4   NaN   NaN
# 25  114.9   NaN   NaN
# 26  221.8   NaN   NaN
# 27  256.0   NaN   NaN

# %%
data
# Out:
#                                                      2019   2020   2021
# ATC
# Digestive system and metabolism_A                   256.0  315.9  325.6
# Antacids_A02A                                         3.7    4.6    4.8
# Gastric ulcer treatment_A02B                         61.2   75.4   81.5
# Diabetes treatment_A10                               67.8   72.7   78.5
# Blood and hematopoietic system_B                     85.2   90.8   93.1
# Cardiovascular_C                                    221.8  240.3  254.9
# Cardiac glycosides_C01A                               0.9    1.0    0.9
# Venotropic agents_C01B                                1.6    1.8    2.0
# Antihypertensives_C02                                 1.8    1.9    1.9
# Diuretics_C03                                        14.4   15.4   15.8
# Beta-blockers_C07                                    13.0   14.0   14.4
# Calcium channel blockers_C08                         43.9   46.8   46.6
# ...

# %%
import matplotlib.pyplot as plt

# 차트 윈도우 제목
plt.figure(num="People chart")

# 차트 제목
plt.title("Pharmaceuticals")

# plt 적용, 한 개의 화면에서 나타나도록 하기 위한 axes 설정
ax = plt.gca()
data.plot(kind='bar', ax=ax)

# x, y 축 제목
plt.xlabel("ATC")
plt.ylabel("Year")

plt.show()

# %%
plt.figure(num="People chart")
 # 차트 제목
plt.title("Pharmaceuticals")
 # plt적용, 한개의 화면에서 나타나도록 하기 위한 axes 설정
ax = plt.gca()
data.plot(kind='line', ax=ax, marker='o')
 # x, y 축 제목
plt.xlabel("ATC")
plt.ylabel("Year")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data['2019'],bins=7,alpha=0.5,label='2019',kde=True)
sns.histplot(data['2020'],bins=7,alpha=0.5,label='2020',color='r',kde=True)
sns.histplot(data['2021'],bins=7,alpha=0.5,label='2021',color='g',kde=True)


plt.xlabel("ATC")
plt.ylabel("Year")
plt.legend()
plt.grid()
plt.show()

# %%
plt.title('Drinking & Weight Seaborn Box Plot Graph')
sns.boxplot(x='2019',y='2020',data=data)
plt.show()

# %%
plt.title('Drinking & Weight Seaborn Box Plot Graph')
sns.boxplot(x='2020',y='2021',data=data)
plt.show()

# %%
plt.title('Drinking & Weight Seaborn Box Plot Graph')
sns.boxplot(x='2019',y='2021',data=data)
plt.show()

# %%
X = data[['2019', '2020']]
y = data['2021']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
y_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(ly_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 4.6561420216428397e-14

# %%
plt.scatter(X_test['2020'], y_test, color='black', label='True values')
plt.scatter(X_test['2021'], y_preds, color='blue', label='Predicted values')
plt.xlabel('2020')
plt.ylabel('2021')
plt.legend()
plt.show()
