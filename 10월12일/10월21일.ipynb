# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel ('C:/Users/mandujoayo/데처프/10월5일/04_data1.xlsx', index_col='area')
data.head()
# Out:
#               2015_good  2016_good  2017_good  2018_good  2019_good  \
# area
# Nationwide         72.0         54         84        135        117
# Metropolitan       72.0         45         77        126        109
# Seoul              97.0         65        113        140        139
# Busan             102.0         89         86        136        163
# Daegu              90.0        103        111        155        148
#
#               2020_good  2015_common  2016_common  2017_common  2018_common  \
# area
# Nationwide          171        267.0          297          265          209
# Metropolitan        150        259.0          290          260          217
# Seoul               168        243.0          277          230          204
# Busan               208        242.0          259          269          212
# Daegu               176        248.0          246          244          196
#
#               ...  2017_bad  2018_bad  2019_bad  2020_bad  2015_verybad  \
# ...

# %%
data
# Out:
#               2015_good  2016_good  2017_good  2018_good  2019_good  \
# area
# Nationwide         72.0         54         84        135        117
# Metropolitan       72.0         45         77        126        109
# Seoul              97.0         65        113        140        139
# Busan             102.0         89         86        136        163
# Daegu              90.0        103        111        155        148
# Incheon            67.0         49         78        140        115
# Gwangju           122.0        151        134        149        117
# Daejeon           111.0         92         83        121        143
# Ulsan             101.0        101        104        162        173
# Sejong              NaN         65         69        130        127
# Gyeonggi           65.0         45         59        123         97
# Gangwon            77.0         65        108        150        159
# Chungbuk           90.0         99        106        117        113
# ...

# %%
data.isnull().sum()
# Out:
# 2015_good       1
# 2016_good       0
# 2017_good       0
# 2018_good       0
# 2019_good       0
# 2020_good       0
# 2015_common     1
# 2016_common     0
# 2017_common     0
# 2018_common     0
# 2019_common     0
# 2020_common     0
# 2015_bad        1
# 2016_bad        0
# 2017_bad        0
# 2018_bad        0
# 2019_bad        0
# 2020_bad        0
# 2015_verybad    1
# 2016_verybad    0
# 2017_verybad    0
# 2018_verybad    0
# 2019_verybad    0
# 2020_verybad    0
# dtype: int64

# %%
avg = data['2015_good'].mean()
data['2015_good']=data['2015_good'].fillna(avg)

avg = data['2015_bad'].mean()
data['2015_bad']=data['2015_bad'].fillna(avg)

avg = data['2015_common'].mean()
data['2015_common']=data['2015_common'].fillna(avg)

# %%
data.isnull().sum()
# Out:
# 2015_good       0
# 2016_good       0
# 2017_good       0
# 2018_good       0
# 2019_good       0
# 2020_good       0
# 2015_common     0
# 2016_common     0
# 2017_common     0
# 2018_common     0
# 2019_common     0
# 2020_common     0
# 2015_bad        0
# 2016_bad        0
# 2017_bad        0
# 2018_bad        0
# 2019_bad        0
# 2020_bad        0
# 2015_verybad    1
# 2016_verybad    0
# 2017_verybad    0
# 2018_verybad    0
# 2019_verybad    0
# 2020_verybad    0
# dtype: int64

# %%
data
# Out:
#                2015_good  2016_good  2017_good  2018_good  2019_good  \
# area
# Nationwide     72.000000         54         84        135        117
# Metropolitan   72.000000         45         77        126        109
# Seoul          97.000000         65        113        140        139
# Busan         102.000000         89         86        136        163
# Daegu          90.000000        103        111        155        148
# Incheon        67.000000         49         78        140        115
# Gwangju       122.000000        151        134        149        117
# Daejeon       111.000000         92         83        121        143
# Ulsan         101.000000        101        104        162        173
# Sejong         91.611111         65         69        130        127
# Gyeonggi       65.000000         45         59        123         97
# Gangwon        77.000000         65        108        150        159
# ...

# %%
import numpy as np
import matplotlib. pyplot as plt
index= np.arange(7)

plt.figure(figsize=(10,4))

data6 = data.loc['Seoul': 'Ulsan', '2017_common': '2020_common']
for year in range (2017, 2021):
    year = str(year)+'_common'
    chartdata = data6[year]
    plt.barh(index, chartdata, label=year)

plt.xlim(120,310)
plt.ylabel('Area')
plt.xlabel('Micrometer')
plt.yticks(index, ['Seoul', 'Busan', 'Daegu', 'Incheon', 'Gwangju',
'Daejeon', 'Ulsan'])
plt.title('2017-2020 Fine Dust (pm10) Common Group Barh Graph')
plt.legend()
plt.show()

# %%
data2015_good = data['2015_good']
data2015_bad = data['2015_bad']
data2015_common = data['2015_common']

labels = ['2015_bad', '2015_good', '2015_common']
# 상자그림 그리기
plt.figure(figsize=(8, 5))
plt.boxplot([data2015_bad,data2015_good,data2015_common],labels=labels)
plt.ylabel('Feature')
plt.xlabel('Value')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:/Users/mandujoayo/데처프/10월5일/04_data2.csv')

# %%
data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
PetalLength = data['PetalLength'] 
PetalWidth = data['PetalWidth']
plt.figure(figsize=(10,4))
plt.scatter(PetalLength, PetalWidth)
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('Iris Petal Scatter Graph')
plt.grid() 
plt.show()

# %%
PetalLength = data['PetalLength'] 
PetalWidth = data['PetalWidth']

SepalLength = data['SepalLength'] 
SepalWidth = data['SepalWidth']

plt.figure(figsize=(10,4))
plt.scatter(PetalLength, PetalWidth, color='r', edgecolor='w', label='PetalLength PetalWidth')
plt.scatter (SepalLength, SepalWidth, color='b', edgecolor='w',label='SepalLength * SepalWidth')
plt.xlabel('Length')
plt.ylabel('Width')
plt.title('Iris Petal Group Scatter Graph')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.boxplot([SepalLength, SepalWidth], labels=['Sepal Length','Sepal Width'], vert=False)
plt.ylabel('Sepal')
plt.xlabel('Value')
plt.title('Iris Sepal Horizontal Box Plot')
plt.show()

# %%
df = pd.read_csv('/Users/mandujoayo/데처프/9월21일/titanic.csv')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
avg = df['Age'].mean()
df['Age']=df['Age'].fillna(avg)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.drop('Cabin',axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
Fare = df['Fare'] 
Pclass = df['Pclass']
plt.figure(figsize=(6,4))
plt.scatter(Pclass, Fare,color='r')
plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.legend()
plt.grid() 
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df = df.copy().head(100)

# %%
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex        Age  \
# 0                             Braund, Mr. Owen Harris    male  22.000000
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                              Heikkinen, Miss. Laina  female  26.000000
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                            Allen, Mr. William Henry    male  35.000000
# ..                                                ...     ...        ...
# ...

# %%
plt.figure(figsize=(10,6))
plt.hist(df['Fare'], bins=10, label='Fare')

plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.legend()
plt.grid()
plt.show()

# %%
age = df.loc[df.Survived== 1, ['Survived', 'Age']]
fare = df.loc[df.Survived== 1, ['Survived', 'Fare']]

plt.figure(figsize=(10,6))
plt.hist(age['Age'],color = 'r' ,bins=50, alpha=0.5, label='Age')
plt.hist(fare['Fare'],color = 'b' ,bins=50, alpha=0.5, label='Fare')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid()
plt.show()

# %%
Fare = df['Fare']
Age = df['Age']

# 상자그림 그리기
plt.figure(figsize=(8, 5))
plt.boxplot([Fare, Age], labels=['Fare', 'Age'], vert=False)
plt.ylabel('Feature')
plt.xlabel('Value')
plt.title('Titanic Fare and Age Horizontal Box Plot')
plt.show()

# %%
data = pd.read_excel ('C:/Users/mandujoayo/데처프/10월12일/05_data1.xlsx')
data.head()
# Out:
#    no  city_code  gender  age_code  height  weight  waist  systolic  \
# 0   1         36       1         9     165      60   72.1       127
# 1   5         41       2        12     155      50   75.2       144
# 2   6         27       1         9     185      85   94.0       114
# 3   7         44       1         9     165      80   93.0       112
# 4   9         41       2        17     150      50   82.0       136
#
#    diastolic  blood_sugar  cholesterol  triglycerides   HDL  LDL  hemoglobin  \
# 0         79           90          188             58  58.0  118        15.0
# 1         89          110          220            171  53.0  133        12.4
# 2         72           86          234            183  50.0  147        16.4
# 3         73          250          119            265  26.0   40        15.7
# 4         65          104          177             61  63.0  101        13.3
#
#    serum  smoking  drinking
# 0    1.1        1         0
# 1    0.7        1         0
# ...

# %%
data.isnull().sum()
# Out:
# no               0
# city_code        0
# gender           0
# age_code         0
# height           0
# weight           0
# waist            0
# systolic         0
# diastolic        0
# blood_sugar      0
# cholesterol      0
# triglycerides    0
# HDL              0
# LDL              0
# hemoglobin       0
# serum            0
# smoking          0
# drinking         0
# dtype: int64

# %%
data6 = data.loc[:,['gender','height','weight', 'waist','drinking','smoking']]
data6.loc[data6['gender']==1,['gender']]='M'
data6.loc[data6['gender']==2,['gender']]='F'
data6.loc[data6['drinking']==0,['drinking']]='Non-drinking'
data6.loc[data6['drinking']==1,['drinking']]='Drinking'
data6.loc[data6['smoking']==1,['smoking']]='Non-smoking'
data6.loc[data6['smoking']==2,['smoking']]='Quit-smoking'
data6.loc[data6['smoking']==3,['smoking']]='Smoking'

# %%
data6
# Out:
#      gender  height  weight  waist      drinking       smoking
# 0         M     165      60   72.1  Non-drinking   Non-smoking
# 1         F     155      50   75.2  Non-drinking   Non-smoking
# 2         M     185      85   94.0      Drinking       Smoking
# 3         M     165      80   93.0      Drinking       Smoking
# 4         F     150      50   82.0  Non-drinking   Non-smoking
# ...     ...     ...     ...    ...           ...           ...
# 2995      F     155      55   68.0      Drinking   Non-smoking
# 2996      M     155      60   79.0  Non-drinking   Non-smoking
# 2997      M     165      60   85.0  Non-drinking   Non-smoking
# 2998      M     180      90   97.0      Drinking   Non-smoking
# 2999      M     160      65   89.8      Drinking  Quit-smoking
#
# [3000 rows x 6 columns]

# %%
drinking = data6.groupby(['gender','drinking'])['drinking'].count()
smoking = data6.groupby(['gender','smoking'])['smoking'].count()
drinking = drinking.to_frame(name='count')
smoking = smoking.to_frame(name='count')
drinking = drinking.reset_index()
smoking = smoking.reset_index()

# %%
drinking
# Out:
#   gender      drinking  count
# 0      F      Drinking    611
# 1      F  Non-drinking    888
# 2      M      Drinking   1086
# 3      M  Non-drinking    415

# %%
fig = plt.figure(figsize=(12,10))
fig.suptitle('2020 Health Check Drinking & Smoking Type Bar Graph',fontweight='bold')
index1 = np.arange(4)
index2 = np.arange(6)

fig.add_subplot(2,1,1)

plt.bar(index1, drinking['count'])
plt.title('Drinking Type')
plt.ylabel('Count')
plt.xticks(index1, ['Non-drinking(M)','Drinking(M)','Non-drinking(F)','Drinking(F)'])

fig.add_subplot(2,1,2)

plt.bar(index2, smoking['count'])
plt.title('Smoking Type')
plt.ylabel('Count')
plt.xticks(index2, ['Non-smoking(M)','Quit-smoking(M)','Smoking(M)','Non-smoking(F)','Quit-smoking(F)','Smoking(F)'])

plt.show()

# %%
data.columns
# Out:
# Index(['no', 'city_code', 'gender', 'age_code', 'height', 'weight', 'waist',
#        'systolic', 'diastolic', 'blood_sugar', 'cholesterol', 'triglycerides',
#        'HDL', 'LDL', 'hemoglobin', 'serum', 'smoking', 'drinking'],
#       dtype='object')

# %%
drinking
# Out:
#   gender      drinking  count
# 0      F      Drinking    611
# 1      F  Non-drinking    888
# 2      M      Drinking   1086
# 3      M  Non-drinking    415

# %%
smoking
# Out:
#   gender       smoking  count
# 0      F   Non-smoking   1422
# 1      F  Quit-smoking     45
# 2      F       Smoking     32
# 3      M   Non-smoking    502
# 4      M  Quit-smoking    519
# 5      M       Smoking    480

# %%
import seaborn as sns
fig = plt.figure(figsize=(12,12))
area1 = fig.add_subplot(2,1,1)
area2 = fig.add_subplot(2,1,2)
ax1 = sns.barplot (x='gender',y='count', hue='drinking', data=drinking, ax=area1)
ax2 = sns.barplot (x='gender',y='count', hue='smoking', data=smoking, ax=area2)
fig.suptitle('2020 Health Check Drinking & Smoking Type Seaborn Bar Graph', fontweight='bold')
area1.set_title('Drinking Type') 
area2.set_title('Smoking Type')
plt.show()

# %%
data6 = data.loc[:,['gender','height','weight', ]]
data6.loc[data6['gender']==1,['gender']]='M'
data6.loc[data6['gender']==2,['gender']]='F'
data6.loc[data6['drinking']==0,['drinking']]='Non-drinking'
data6.loc[data6['drinking']==1,['drinking']]='Drinking'
data6.loc[data6['smoking']==1,['smoking']]='Non-smoking'
data6.loc[data6['smoking']==2,['smoking']]='Quit-smoking'
data6.loc[data6['smoking']==3,['smoking']]='Smoking'
