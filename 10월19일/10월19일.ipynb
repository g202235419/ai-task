# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel ('C:/Users/mandujoayo/데처프/10월12일/05_data1.xlsx')
data.head()
# Out:
#    no  city_code  gender  age_code  height  weight  waist  systolic  \
# 0   1         36       1         9     165      60   72.1       127
# 1   5         41       2        12     155      50   75.2       144
# 2   6         27       1         9     185      85   94.0       114
# 3   7         44       1         9     165      80   93.0       112
# 4   9         41       2        17     150      50   82.0       136
#
#    diastolic  blood_sugar  cholesterol  triglycerides   HDL  LDL  hemoglobin  \
# 0         79           90          188             58  58.0  118        15.0
# 1         89          110          220            171  53.0  133        12.4
# 2         72           86          234            183  50.0  147        16.4
# 3         73          250          119            265  26.0   40        15.7
# 4         65          104          177             61  63.0  101        13.3
#
#    serum  smoking  drinking
# 0    1.1        1         0
# 1    0.7        1         0
# ...

# %%
data
# Out:
#         no  city_code  gender  age_code  height  weight  waist  systolic  \
# 0        1         36       1         9     165      60   72.1       127
# 1        5         41       2        12     155      50   75.2       144
# 2        6         27       1         9     185      85   94.0       114
# 3        7         44       1         9     165      80   93.0       112
# 4        9         41       2        17     150      50   82.0       136
# ...    ...        ...     ...       ...     ...     ...    ...       ...
# 2995  7648         31       2        11     155      55   68.0       132
# 2996  7650         42       1        13     155      60   79.0       123
# 2997  7651         41       1         9     165      60   85.0       118
# 2998  7652         42       1         9     180      90   97.0       148
# 2999  7659         44       1        11     160      65   89.8       125
#
#       diastolic  blood_sugar  cholesterol  triglycerides   HDL  LDL  \
# ...

# %%
data6 = data.loc[:,['gender','height','weight', 'waist','drinking','smoking']]
data6.loc[data6['gender']==1,['gender']]='M'
data6.loc[data6['gender']==2,['gender']]='F'
data6.loc[data6['drinking']==0,['drinking']]='Non-drinking'
data6.loc[data6['drinking']==1,['drinking']]='Drinking'
data6.loc[data6['smoking']==1,['smoking']]='Non-smoking'
data6.loc[data6['smoking']==2,['smoking']]='Quit-smoking'
data6.loc[data6['smoking']==3,['smoking']]='Smoking'

# %%
drinking = data6.groupby(['gender','drinking'])['drinking'].count()
smoking = data6.groupby(['gender','smoking'])['smoking'].count()
drinking = drinking.to_frame(name='count')
smoking = smoking.to_frame(name='count')
drinking = drinking.reset_index()
smoking = smoking.reset_index()

# %%
maledata=data6.loc[data6.gender == 'M', ['gender', 'height', 'weight', 'waist', 'drinking', 'smoking']]
femaledata=data6.loc[data6.gender == 'F', ['gender', 'height', 'weight','waist', 'drinking', 'smoking']]

# %%
plt.figure(figsize=(10,6))
sns.histplot(maledata['weight'], bins=8, alpha=0.5,label='Male') 
sns.histplot(femaledata['weight'],bins=8, alpha=0.5, label='Female',
color='r')
plt.xlim(20,130) 
plt.xlabel('weight')
plt.ylabel('count')
plt.title('Weight Seaborn Histogram')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(maledata['waist'],bins=7,alpha=0.5,label='Male',kde=True)
sns.histplot(femaledata['waist'],bins=7,alpha=0.5,label='Female',color='r',kde=True)

plt.xlim(40,130)
plt.xlabel('waist')
plt.ylabel('count')
plt.title('Waist Seaborn Histogram - KDE(Kernel Density Estimator)')
plt.legend()
plt.grid()
plt.show()

# %%
data = pd.read_csv ('C:/Users/mandujoayo/데처프/10월19일/age.csv')

# %%
data
# Out:
#       Diameter  Height  Whole_Weight  Viscra_Weight  Shell_Weight  Group
# 0        0.525   0.195        1.3700         0.2955        0.4070    2.0
# 1        0.275   0.095        0.2170         0.0435        0.0900    1.0
# 2        0.470   0.165        0.9975         0.2420        0.3300    0.0
# 3        0.450   0.140        1.0130         0.2160        0.3600    0.0
# 4        0.380   0.135        0.6810         0.1420        0.1700    0.0
# ...        ...     ...           ...            ...           ...    ...
# 997      0.450   0.160        0.9980         0.2140        0.3010    0.0
# 998      0.260   0.100        0.1920         0.0585        0.0700    1.0
# 999      0.505   0.175        1.2075         0.2620        0.3900    0.0
# 1000     0.300   0.105        0.3040         0.0610        0.0805    1.0
# 1001     0.465   0.150        1.0270         0.1880        0.1760    0.0
#
# [1002 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['Diameter', 'Height', 'Whole_Weight', 'Viscra_Weight', 'Shell_Weight',
#        'Group'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Group',data=data)
# Out:
# <AxesSubplot:xlabel='Group', ylabel='count'>

# %%
Year0=data.loc[data.Group==0.0,['Diameter', 'Height', 'Whole_Weight', 'Viscra_Weight', 'Shell_Weight']]
Year1=data.loc[data.Group==1.0,['Diameter', 'Height', 'Whole_Weight', 'Viscra_Weight', 'Shell_Weight']]
Year2=data.loc[data.Group==2.0,['Diameter', 'Height', 'Whole_Weight', 'Viscra_Weight', 'Shell_Weight']]

# %%
Year0
# Out:
#       Diameter  Height  Whole_Weight  Viscra_Weight  Shell_Weight
# 2        0.470   0.165        0.9975         0.2420        0.3300
# 3        0.450   0.140        1.0130         0.2160        0.3600
# 4        0.380   0.135        0.6810         0.1420        0.1700
# 6        0.435   0.140        0.7535         0.1555        0.2325
# 7        0.405   0.150        0.7035         0.1340        0.1885
# ...        ...     ...           ...            ...           ...
# 991      0.470   0.150        0.9205         0.2435        0.2675
# 994      0.480   0.190        1.2955         0.3225        0.3650
# 997      0.450   0.160        0.9980         0.2140        0.3010
# 999      0.505   0.175        1.2075         0.2620        0.3900
# 1001     0.465   0.150        1.0270         0.1880        0.1760
#
# [416 rows x 5 columns]

# %%
plt.figure(figsize=(10,6))
sns.histplot(Year0['Diameter'],bins=7,alpha=0.5,label='0.0',kde=True)
sns.histplot(Year1['Diameter'],bins=7,alpha=0.5,label='1.0',color='r',kde=True)
sns.histplot(Year2['Diameter'],bins=7,alpha=0.5,label='2.0',color='b',kde=True)

plt.xlim(0,1)
plt.xlabel('Diameter')
plt.ylabel('count')
plt.title('Waist Seaborn Histogram - KDE(Kernel Density Estimator)')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Drinking & Weight Seaborn Box Plot Graph')
sns.boxplot(x='Group',y='Height',data=data)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.title('Drinking & Weight Seaborn Box Plot Graph')
sns.boxplot(x='Group',y='Diameter', data=data)
plt.autoscale()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='Group',y='Diameter',data=data)
# Out:
# <AxesSubplot:xlabel='Group', ylabel='Diameter'>

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='Group',y='Height',data=data)
# Out:
# <AxesSubplot:xlabel='Group', ylabel='Height'>

# %%
data.drop('Group',axis = 1, inplace = True)

# %%
plt.figure(figsize=(13,10))
plt.title('8×8 Heat Map Graph')

correlation_data= data.corr()

sns.heatmap(correlation_data, annot=True, cmap='RdYlGn')
# Out:
# <AxesSubplot:title={'center':'8×8 Heat Map Graph'}>

# %%
pp = sns.pairplot(data,height=3.3,aspect=1.3)

# %%
data = pd.read_csv ('C:/Users/mandujoayo/데처프/10월19일/age.csv')

# %%
data1 =  data.loc[:,['Diameter', 'Height','Group']]

# %%
data1
# Out:
#       Diameter  Height  Group
# 0        0.525   0.195    2.0
# 1        0.275   0.095    1.0
# 2        0.470   0.165    0.0
# 3        0.450   0.140    0.0
# 4        0.380   0.135    0.0
# ...        ...     ...    ...
# 997      0.450   0.160    0.0
# 998      0.260   0.100    1.0
# 999      0.505   0.175    0.0
# 1000     0.300   0.105    1.0
# 1001     0.465   0.150    0.0
#
# [1002 rows x 3 columns]

# %%
data1.loc[data['Diameter'] >= 0.4,['Diameter']]='BIG'
data1.loc[data['Diameter'] < 0.4,['Diameter']]='SMALL'

data1.loc[data['Height'] >= 0.15,['Height']]='BIG'
data1.loc[data['Height'] < 0.15,['Height']]='SMALL'

# %%
data1
# Out:
#      Diameter Height  Group
# 0         BIG    BIG    2.0
# 1       SMALL  SMALL    1.0
# 2         BIG    BIG    0.0
# 3         BIG  SMALL    0.0
# 4       SMALL  SMALL    0.0
# ...       ...    ...    ...
# 997       BIG    BIG    0.0
# 998     SMALL  SMALL    1.0
# 999       BIG    BIG    0.0
# 1000    SMALL  SMALL    1.0
# 1001      BIG    BIG    0.0
#
# [1002 rows x 3 columns]

# %%
Diameter = data1.groupby(['Group', 'Diameter'])['Diameter'].count()
Height = data1.groupby(['Group', 'Height'])['Height'].count()

Diameter = Diameter.to_frame(name='count')
Height = Height.to_frame(name='count')

Diameter = Diameter.reset_index()
Height = Height.reset_index()

# %%
Diameter
# Out:
#    Group Diameter  count
# 0    0.0      BIG    392
# 1    0.0    SMALL     24
# 2    1.0      BIG     26
# 3    1.0    SMALL    400
# 4    2.0      BIG    160

# %%
Height
# Out:
#    Group Height  count
# 0    0.0    BIG    264
# 1    0.0  SMALL    152
# 2    1.0    BIG      7
# 3    1.0  SMALL    419
# 4    2.0    BIG    159
# 5    2.0  SMALL      1
